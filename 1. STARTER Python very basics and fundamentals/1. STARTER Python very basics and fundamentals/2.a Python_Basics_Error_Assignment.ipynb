# %% [markdown]
# # 🐍 Python Basics Assignment – Error-Focused Challenges
#
# These assignments are designed to help you debug and learn from common Python mistakes. For each question:
#
# - Fix the code
# - Explain the error
# - Write the correct output
# - Add a 'What I Learned' summary at the end
#
# ---

# %% [markdown]
# ## 1. Variable Madness

# %%
num1 = '10'
num2 = 5
result = num1 + num2
print("Result:", result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-9eff7b8acf9c> in <cell line: 0>()
#       1 num1 = '10'
#       2 num2 = 5
# ----> 3 result = num1 + num2
#       4 print("Result:", result)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## 2. Mystery Indentation

# %%
x = 5
if x > 3:
print("Greater than 3")
  print("Still in the if")
print("Outside if")

# %% [markdown]
# ## 3. Loop Trap

# %%
i = 10
while i < 10:
    print(i)
    i = i + 1

# %% [markdown]
# ## 4. List Out of Range

# %%
my_list = [10, 20, 30]
print(my_list[3])

# %% [markdown]
# ## 5. The String Surprise

# %%
text = "Python"
print(text[1:100])

# %% [markdown]
# ## 6. Sum It Up... or Not

# %%
my_list = [1, 2, 3, '4']
total = sum(my_list)
print("Total:", total)

# %% [markdown]
# ## 7. The Conditional Confusion

# %%
a = 5
b = 10
if a > b:
    print("a is greater")
else:
    print("b is greater")
print("Difference is", a - b)

# %% [markdown]
# ## 8. Input Intuition

# %%
num = input("Enter a number: ")
print("Double is:", num * 2)

# %% [markdown]
# ## 9. List Mutation Mayhem

# %%
my_list = [1, 2, 3]
new_list = my_list
new_list.append(4)
print(my_list)

# %% [markdown]
# ## 10. The Range Riddle

# %%
for i in range(1, 5.5):
    print(i)

# %% [markdown]
# ## 🔥 Bonus – Bug Injection
# Write a program that takes a list of numbers and prints the average. Intentionally include one bug in your first version. Then explain the bug and fix it in a second version.
