# %% [markdown]
# # Python Basics to Intermediate Questions (Till Lists)

# %% [markdown]
# ## 1. Print "Hello, World!" in Python

# %% [markdown]
# ## 2. Assign the value 10 to a variable `x` and print it

# %% [markdown]
# ## 3. Take user input for a name and print "Hello, <name>!"

# %% [markdown]
# ## 4. Swap two numbers without using a third variable

# %% [markdown]
# ## 5. Check if a number is even or odd

# %% [markdown]
# ## 6. Write a program to check if a given number is prime

# %% [markdown]
# ## 7. Print numbers from 1 to 10 using a loop

# %% [markdown]
# ## 8. Print the multiplication table of a given number using a loop

# %% [markdown]
# ## 9. Find the sum of all numbers in a given range

# %% [markdown]
# ## 10. Find the factorial of a number using a loop
