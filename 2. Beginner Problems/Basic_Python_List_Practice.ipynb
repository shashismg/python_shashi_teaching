# %% [markdown]
# # 📝 Basic Python List Practice Notebook
# This notebook contains **10 basic-level Python list challenges** that still require logic to solve. 💡
#
# Try solving each problem by writing Python code in the cells below. 🚀
#
# ---

# %% [markdown]
# ## 1️⃣ Find the Sum of All Elements

# %%
numbers = [3, 1, 4, 1, 5, 9]
# Your code here
sum=0
for i in numbers:
  sum=sum+i

print(sum)
# Out:
# 23

# %% [markdown]
# ## 2️⃣ Count Even and Odd Numbers

# %%
nums = [10, 21, 4, 45, 66, 93, 1]
# Your code here
even=0
odd=0
for i in nums:
  if i%2==0:
    even=even+1
  else:
    odd=odd+1

print(f"Even numbers are: {even}")
print(f"Odd numbeers are: {odd}")
# Out:
# Even numbers are: 3
# Odd numbeers are: 4

# %% [markdown]
# ## 3️⃣ Reverse a List (Without `[::-1]`)

# %%
nums = [1, 2, 3, 4, 5]
# Your code here

i=0
j=4
while i<j:
  temp=nums[i]
  nums[i]=nums[j]
  nums[j]=temp
  i=i+1
  j=j-1

print(nums)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 4️⃣ Find the Largest Number

# %%
nums = [10, 20, 4, 45, 99, 5]
# Your code here

# %% [markdown]
# ## 5️⃣ Remove All Occurrences of an Element

# %%
nums = [1, 2, 3, 2, 4, 2, 5]
remove_element = 2
# Your code here
for i in nums:
  if i==2:
    nums.remove(i)

print(nums)
# Out:
# [1, 3, 4, 5]

# %% [markdown]
# ## 6️⃣ Find Index of an Element (Without `index()`)

# %%
nums = [10, 20, 30, 40, 50]
search_element = 30
# Your code here
for i in range(0,len(nums)):
  if nums[i]==30:
    print(i)
# Out:
# 2

# %% [markdown]
# ## 7️⃣ Swap First and Last Element

# %%
nums = [1, 2, 3, 4, 5]
# Your code here
i=0
j=4

temp=nums[i]
nums[i]=nums[j]
nums[j]=temp

print(nums)
# Out:
# [5, 2, 3, 4, 1]

# %% [markdown]
# ## 8️⃣ Check If a List is Sorted

# %%
nums = [1, 2, 3, 4, 5]
# Your code here
flag=0
le=len(nums)-1
for i in range(le):
  if nums[i]>nums[i+1]:
    flag=1
    break
if flag==1:
  print('list is not sorted')
else:
 print('list is sorted')
# Out:
# list is sorted

# %% [markdown]
# ## 9️⃣ Merge Two Lists Alternately

# %%
list1 = [1, 3, 5]
list2 = [2, 4, 6]
# Your code here
new_list=[]
for i in range(len(list1)):
  new_list.append(list1[i])
  new_list.append(list2[i])

print(new_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## 🔟 Count Occurrences of Each Element

# %%
nums = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]
# Your code here
d={}
for i in nums:
  d[i]=d.get(i,0)+1

for i, j in d.items():
  print(f"{i} : {j} times")
# Out:
# 1 : 1 times
# 2 : 2 times
# 3 : 3 times
# 4 : 4 times
