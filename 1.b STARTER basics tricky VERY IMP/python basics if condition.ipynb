# %%
x=10
if x:
  print("true")
else:
  print("false")

# %%
x=-10
if x:
  print("true")
else:
  print("false")
# Out:
# true

# %%
x=0
if x:
  print("true")
else:
  print("false")

# %%
x=[]
if x:
  print("true")
else:
  print("false")
# Out:
# false

# %%
x=[11, 22, 33]
if x:
  print("true")
else:
  print("false")
# Out:
# true

# %%
x="sdfsdfsdf"
if x:
  print("true")
else:
  print("false")
# Out:
# true

# %%
if True:
  print("true")
else:
  print("false")

# %%
x=False
if x:
  print("true")
else:
  print("false")
