# %% [markdown]
# # 🚀 Python List Practice Notebook
# This notebook contains **10 just-above-beginner Python list challenges**.
#
# Try solving each problem by writing Python code in the cells below. 💡
#
# ---

# %% [markdown]
# ## 1️⃣ Remove Duplicates & Sort

# %%
numbers = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# Your code here
n=[]

for i in numbers:
  if i not in n:
    n.append(i)

print(n)
# Out:
# [3, 1, 4, 5, 9, 2, 6]

# %% [markdown]
# ## 2️⃣ Find Second Largest Number

# %%
nums = [10, 20, 4, 45, 98, 99, 5]
# Your code here
n=len(nums)
for i in range(n):
  if i==2:
    break
  for j in range(n-i-1):
    if nums[j]>nums[j+1]:
      temp=nums[j]
      nums[j]=nums[j+1]
      nums[j+1]=temp

print(nums[-2])
# Out:
# 98

# %%
nums = [10, 20, 4, 45, 98, 99, 5]
first=nums[1]
second=nums[0]
for i in range(2,len(nums)):
  if nums[i]>first:
    temp=first
    first=nums[i]
    second=temp

print(f'first: {first}')
print(f'second: {second}')
# Out:
# first: 99
# second: 98

# %% [markdown]
# ## 3️⃣ Rotate List Right by K

# %%
nums = [1, 2, 3, 4, 5]
k = 2
# Your code here
#nums = [4,5,1,2,3]

# %% [markdown]
# ## 4️⃣ Merge Two Sorted Lists

# %%
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]
newlist = []

n1 = len(list1)
n2 = len(list2)

# Your code here
list=list1+list2
print(list)
# Out:
# [1, 3, 5, 7, 2, 4, 6, 8]

# %%
list1 = [1, 3, 5, 7]
list2 = [2, 4, 6, 8]

newlist = []

n1 = len(list1)
n2 = len(list2)

m=0
n=0

while(m<n1 and n<n2):
  if list1[m] < list2[n]:
    newlist.append(list1[m])
    m+=1
  else:
    newlist.append(list2[n])
    n+=1

while(m < n1):
  newlist.append(list1[m])
  m+=1

while(n < n2):
  newlist.append(list2[n])
  n+=1

print(newlist)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ## 5️⃣ Find All Pairs That Sum to K

# %%
nums = [1, 2, 3, 4, 5, 6, 7, 8]
k = 9
l=[]
s=set()

for i in nums:
  n = k-i
  if n in s:
    l.append((n,i))

  s.add(i)
print(l)
print(s)
# Out:
# [(4, 5), (3, 6), (2, 7), (1, 8)]
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# ## 6️⃣ Flatten a Nested List

# %%
nested = [[1, 2, [3]], 4, [5, 6], [[7, 8]]]
# Your code here

# %% [markdown]
# ## 7️⃣ Find Missing Number in a Consecutive List

# %%
nums = [11, 12, 13, 15,16, 17, 18]
# Your code here
j=nums[0]
n=nums[-1]

while j<n:
  if j not in nums:
    print(j)
    break
  else:
    j+=1
# Out:
# 14

# %% [markdown]
# ## 8️⃣ Move All Zeroes to End

# %%
nums = [0, 1, 0, 3, 12, 0, 5]
# Your code here
l=[]
l1=[]

for i in nums:
  if i ==0:
    l.append(i)
  else:
    l1.append(i)

l1.extend(l)
print(l1)
# Out:
# [1, 3, 12, 5, 0, 0, 0]

# %% [markdown]
# ## 9️⃣ Find Most Frequent Element

# %%
nums = [1, 3, 1, 3, 2, 1, 4, 1, 5, 1]
# Your code here
d={}

for i in nums:
  d[i]=d.get(i,0)+1
print(d)

maximum=max(d, key=d.get)
print(maximum)
# Out:
# {1: 5, 3: 2, 2: 1, 4: 1, 5: 1}
# 1

# %% [markdown]
# ## 🔟 Remove Elements That Appear More Than Once

# %%
nums = [4, 5, 6, 7, 5, 6, 8, 9]
# Your code here
l=[]

for i in nums:
  if i not in l:
    l.append(i)
print(l)
# Out:
# [4, 5, 6, 7, 8, 9]
